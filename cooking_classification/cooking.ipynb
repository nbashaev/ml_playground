# %% [markdown]
# # Predicting cuisine type by ingredients

# %%
# %matplotlib inline

import gc
import re

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.multiclass import OneVsRestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
train_raw_data = pd.read_json('train.json').set_index('id')
test_raw_data = pd.read_json('test.json').set_index('id')

train_raw_data.head()
# Out:
#            cuisine                                        ingredients
# id
# 10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 22213       indian                [water, vegetable oil, wheat, salt]
# 13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
fig = plt.figure(figsize=(12,8))
ax = sns.countplot(y=train_raw_data['cuisine'])

# %%
df = pd.concat([train_raw_data.drop("cuisine", axis=1), test_raw_data], axis=0)
df['ingredients'] = df['ingredients'].apply(','.join)
y = train_raw_data['cuisine']

traindex = train_raw_data.index
testdex = test_raw_data.index
df_index = df.index

del train_raw_data, test_raw_data
gc.collect()

df.head()
# Out:
#                                              ingredients
# id
# 10259  romaine lettuce,black olives,grape tomatoes,ga...
# 25693  plain flour,ground pepper,salt,tomatoes,ground...
# 20130  eggs,pepper,salt,mayonaise,cooking oil,green c...
# 22213                     water,vegetable oil,wheat,salt
# 13162  black pepper,shallots,cornflour,cayenne pepper...

# %%
ingredients = pd.Series(','.join(df['ingredients'].tolist()).split(','))
v_counts = ingredients.value_counts()

v_counts
# Out:
# salt                                              22534
# onions                                            10008
# olive oil                                          9889
# water                                              9293
# garlic                                             9171
# sugar                                              8064
# garlic cloves                                      7772
# butter                                             6078
# ground black pepper                                5990
# all-purpose flour                                  5816
# vegetable oil                                      5516
# pepper                                             5508
# eggs                                               4262
# soy sauce                                          4120
# kosher salt                                        3930
# green onions                                       3817
# tomatoes                                           3812
# large eggs                                         3700
# carrots                                            3542
# unsalted butter                                    3474
# ground cumin                                       3431
# extra-virgin olive oil                             3424
# black pepper                                       3291
# milk                                               2851
# chili powder                                       2519
# red bell pepper                                    2434
# oil                                                2426
# purple onion                                       2372
# scallions                                          2372
# grated parmesan cheese                             2367
#                                                   ...
# riblets                                               1
# chicken consomme                                      1
# creamer potatoes                                      1
# passover cake meal                                    1
# light syrup                                           1
# lamb cubes                                            1
# fresh ham butt                                        1
# au jus gravy                                          1
# macarons                                              1
# Quorn crumbles                                        1
# salt free herb seasoning                              1
# Yakisoba sauce                                        1
# mineral water                                         1
# Cavenders Greek Seasoning                             1
# bertolli vidalia onion with roast garlic sauc         1
# reduced sodium condensed cream of chicken soup        1
# KnorrÂ® Pasta Sidesâ„¢ - Chicken flavor               1
# Swanson Vegetable Broth                               1
# Pam Cooking Spray                                     1
# butter salt                                           1
# lap cheong                                            1
# alaskan halibut                                       1
# pita wraps                                            1
# pie pumpkin                                           1
# topside steak                                         1
# barilla piccolini mini                                1
# reduced sugar ketchup                                 1
# low sodium parmesan cheese                            1
# raspberry lambic                                      1
# frozen cherries                                       1
# Length: 7148, dtype: int64

# %%
num_to_show = np.sum(v_counts <= 10)
print('The overall number of ingredients is {0} while {1} of them appear 10 or less times'.format(v_counts.shape[0], num_to_show))

fig = plt.figure(figsize=(12,8))
ax = v_counts[-num_to_show:].plot.hist(bins=10, rwidth=0.9)
# Out:
# The overall number of ingredients is 7148 while 4598 of them appear 10 or less times

# %%
def unify(word_list):
    word_list = word_list.lower()
    word_list = re.sub(',', ' ', word_list)
    word_list = re.sub('and', ' ', word_list)
    word_list = re.sub(' +', ' ', word_list).strip()
    return word_list

df['ingredients'] = df['ingredients'].apply(unify)
ingredients = pd.Series(' '.join(df['ingredients'].tolist()).split(' '))
v_counts = ingredients.value_counts()

v_counts
# Out:
# pepper              32180
# salt                30542
# oil                 29076
# garlic              23624
# ground              22826
# fresh               22164
# sauce               16354
# sugar               15637
# onions              15450
# cheese              14722
# chicken             14312
# olive               13572
# black               13229
# water               12226
# red                 11538
# flour               11104
# butter              10786
# tomatoes            10728
# green               10687
# powder              10308
# chopped              9802
# cloves               9422
# juice                8974
# white                8637
# onion                8615
# eggs                 8170
# cream                7700
# rice                 7681
# cilantro             7432
# milk                 7295
#                     ...
# ready-made              1
# crockerâ„¢              1
# falafel                 1
# farmhouse               1
# biga                    1
# blacan                  1
# camellia                1
# chua                    1
# ferns                   1
# ketjap                  1
# originalsâ®             1
# spear                   1
# pinipig                 1
# bayonne                 1
# kampyo                  1
# arctic                  1
# bã©nã©dictine           1
# meat-filled             1
# heath                   1
# dinosaur                1
# nen                     1
# hickory-flavored        1
# steamersâ„¢             1
# trenne                  1
# crawford                1
# sablefish               1
# mazolaâ®                1
# hakusai                 1
# farmsâ®                 1
# petrale                 1
# Length: 3282, dtype: int64

# %%
num_to_show = np.sum(v_counts <= 10)
print('The overall number of ingredients is {0} while {1} of them appear 10 or less times'.format(v_counts.shape[0], num_to_show))

fig = plt.figure(figsize=(12,8))
ax = v_counts[-num_to_show:].plot.hist(bins=10, rwidth=0.9)
# Out:
# The overall number of ingredients is 3282 while 1670 of them appear 10 or less times

# %%
vect = CountVectorizer(tokenizer=lambda x: x.split(' '))
dummies = vect.fit_transform(df['ingredients'])
new_df = pd.DataFrame(dummies.todense(), columns=vect.get_feature_names())
new_df.index = df_index

columns_list = v_counts[v_counts <= 2].index
new_df = new_df.drop(columns=columns_list)

X = new_df.loc[traindex,:]
X_test = new_df.loc[testdex,:]

del new_df, dummies
gc.collect()

print(X.shape)
print(X_test.shape)
# Out:
# (39774, 2399)
# (9944, 2399)

# %%
columns_list.tolist()
# Out:
# ['cara',
#  'cup',
#  'maniã©',
#  'm&ms',
#  'muesli',
#  'kokum',
#  'komatsuna',
#  'breadfruit',
#  'foster',
#  'moscato',
#  'yaki-nori',
#  'tangzhong',
#  'ficelle',
#  'usukuchi',
#  'carambola',
#  'manischewitz',
#  'eating',
#  '3',
#  'klondike',
#  'ortega',
#  'genoise',
#  'pete',
#  'scallopini',
#  'mora',
#  'alphabet',
#  'beurre',
#  'popped',
#  'uni',
#  'panch',
#  'gomashio',
#  'tangelos',
#  'bacardi',
#  'soft-shell',
#  'garl',
#  'paratha',
#  'prime',
#  'shortcakes',
#  'reblochon',
#  'crosswise',
#  'one',
#  'beluga',
#  'sato',
#  'multigrain',
#  "food's",
#  'vital',
#  "it'",
#  'pam',
#  'tvp',
#  'chilean',
#  'wagon',
#  'tuttorosso',
#  'mozarella',
#  'skinned',
#  'godiva',
#  'success',
#  'lambs',
#  'flan',
#  'fast-rising',
#  'seamless',
#  'tsuyu',
#  'blendsâ®',
#  'sâ®',
#  'teleme',
#  'cajun-creole',
#  'braggs',
#  'dips',
#  'racks',
#  'elderflower',
#  'castellane',
#  'herbsaint',
#  'herbal',
#  'korma',
#  'chuno',
#  'langoustines',
#  'whiting',
#  'vi',
#  'wheatberries',
#  'conimex',
#  'monde',
#  'pummelo',
#  'reposado',
#  'petit',
#  'azuki',
#  'brisã©e',
#  'unsalt',
#  'marrons',
#  'lb.',
#  'cola-flavored',
#  'jimmies',
#  'dasheen',
#  'thickeners',
#  'fashioned',
#  'pao',
#  'refined',
#  'trotters',
#  'cow',
#  'royal',
#  'progressoâ„¢',
#  'butter!',
#  'trumpet',
#  'dragees',
#  'saki',
#  'cuervo',
#  'foods',
#  'frangipane',
#  'myzithra',
#  'tapatio',
#  'sections',
#  'padron',
#  'pho',
#  'to',
#  'loose',
#  'suckling',
#  'peppadews',
#  'sweetbreads',
#  'alum',
#  'jamaica',
#  'tail',
#  'comino',
#  'borage',
#  'fondant',
#  'rockfish',
#  'tricolor',
#  'breyersâ®',
#  'cascabel',
#  'blackstrap',
#  'chai',
#  'tostitos',
#  'wish-boneâ®',
#  'malted',
#  'karashi',
#  'bacardiâ®',
#  'pastina',
#  'ounc',
#  'tropical',
#  "hellmann's",
#  'robusto',
#  'moroccan',
#  '1/2',
#  'ceylon',
#  'passover',
#  'strained',
#  'knoblauch',
#  'szechuan',
#  'high-gluten',
#  'zero',
#  'jimmy',
#  'wolf',
#  'kung',
#  'bhaji',
#  'salsify',
#  'tagliarini',
#  'cold-smoked',
#  'matzos',
#  'nugget',
#  'foodsâ®',
#  'sucralose',
#  'kirschwasser',
#  'non-dairy',
#  'chitterlings',
#  'kasu',
#  'chablis',
#  'wesson',
#  'ginkgo',
#  'nestle',
#  "o'brien",
#  'cole',
#  'poussins',
#  'zabaglione',
#  'frogs',
#  'finger',
#  'serving',
#  'cummin',
#  'mostarda',
#  'liverwurst',
#  'mentaiko',
#  'fowl',
#  'tex-mex',
#  'sambhar',
#  'jonshonvilleâ®',
#  'hing',
#  'tuaca',
#  'raspberri',
#  'linguisa',
#  'undiluted',
#  'pã¢te',
#  'hamachi',
#  'papalo',
#  '(14',
#  'believ',
#  'e',
#  'osetra',
#  'taiwanese',
#  'needles',
#  'pignolis',
#  'casing',
#  'nonpareils',
#  'moss',
#  'matsutake',
#  'ox',
#  'sheet',
#  'tallow',
#  'conch',
#  'no-calorie',
#  'knuckle',
#  'caponata',
#  'porter',
#  'truvã\xadaâ®',
#  'shishito',
#  'robiola',
#  'alfredostyle',
#  'fisher',
#  'fast',
#  'cross',
#  'pod',
#  '2',
#  'moulard',
#  'pompano',
#  'mellow',
#  'nappa',
#  'lavash',
#  'sherbet',
#  'dean',
#  'williams',
#  'huitlacoche',
#  'dukkah',
#  'kalamansi',
#  'jif',
#  'beaters',
#  'boysenberries',
#  'quorn',
#  'hoop',
#  'laughing',
#  'kashmiri',
#  'jose',
#  'aspic',
#  't-bone',
#  'deviled',
#  'anasazi',
#  'razor',
#  'pepperocini',
#  'master',
#  'chuka',
#  'earth',
#  'high',
#  'perch',
#  'family',
#  'barolo',
#  'sack',
#  'double-dark',
#  'yuzukosho',
#  'nama',
#  'cholesterol',
#  'legumes',
#  'filled',
#  'italian-style',
#  'chapatti',
#  'carp',
#  'dr',
#  'poire',
#  'america',
#  'speck',
#  'levain',
#  'sides',
#  'grassfed',
#  'oigatsuo',
#  'drum',
#  'arepa',
#  'jiffy',
#  'st',
#  'terrine',
#  'cortl',
#  'beau',
#  'wingettes',
#  'noodl',
#  'bison',
#  'colorado',
#  'part',
#  'breakstoneâ€™s',
#  'triscuits',
#  'raclette',
#  'rooster',
#  'abalone',
#  'cauliflowerets',
#  'butter-flavored',
#  'cabrales',
#  'fen',
#  'heeng',
#  'e-fu',
#  'delallo',
#  'roughy',
#  'piri-piri',
#  'mezzetta',
#  "d'asti",
#  'culinary',
#  'yodel',
#  'burrito',
#  'masago',
#  'parslei',
#  'lobsters',
#  'cottag',
#  'chamomile',
#  'specials',
#  'branston',
#  'tuong',
#  'blended',
#  'hickory',
#  'redcurrant',
#  'buttercup',
#  'kroger',
#  'lovage',
#  'ngo',
#  'masur',
#  'lesser',
#  'angled',
#  'ploy',
#  'rapini',
#  'crouton',
#  'bream',
#  'boquerones',
#  'milkfat',
#  'hierba',
#  'hubbard',
#  'no-chicken',
#  'vadouvan',
#  'atlantic',
#  'hillshire',
#  "breakstone's",
#  'domaine',
#  'cappuccino',
#  'kisses',
#  'pansies',
#  'tyson',
#  'guanabana',
#  'chocolatecovered',
#  'teff',
#  'bã¢tarde',
#  'manouri',
#  'sobrasada',
#  'pointed',
#  'hyssop',
#  'lillet',
#  'awase',
#  'chex',
#  'zatarains',
#  'marble',
#  'pastrami',
#  'vegeta',
#  "french's",
#  'dubliner',
#  'creationsâ®',
#  'vindaloo',
#  'seven',
#  'stolichnaya',
#  'margherita',
#  'madagascar',
#  'dangmyun',
#  'shad',
#  'scones',
#  'arthur',
#  'wholesome',
#  'cucuzza',
#  'doughnuts',
#  'braised',
#  'harusame',
#  'orgeat',
#  'opo',
#  'brill',
#  'half-',
#  'branca',
#  'brains',
#  'cai',
#  'bellpepper',
#  'pina',
#  'nashi',
#  'taste',
#  'szu',
#  'cordial',
#  'nonhydrogenated',
#  'toasts',
#  'slim',
#  'creami',
#  'torpedo',
#  'superior',
#  'shiraz',
#  'toulouse',
#  'taglierini',
#  'breaded',
#  'chipped',
#  'cavenders',
#  'brew',
#  'tomato-',
#  'chang',
#  'submarine',
#  'jambon',
#  'quahog',
#  'tupelo',
#  'ikura',
#  'winesap',
#  'carbonate',
#  'straight',
#  'fern',
#  'dzem',
#  'preshred',
#  'popsicle',
#  'nigari',
#  'special',
#  'bermuda',
#  'mojo',
#  'k',
#  'tuscan',
#  'longan',
#  'stellette',
#  'asakusa',
#  'baobab',
#  'lecithin',
#  'madeleine',
#  'casa',
#  'hushpuppy',
#  'store-bought',
#  'mixers',
#  'bowls',
#  'hots',
#  'hoi',
#  'bob',
#  'farfalline',
#  'tat',
#  'hachiya',
#  'morcilla',
#  'fettuccini',
#  'conger',
#  'membrillo',
#  'layer',
#  'ridged',
#  'pop',
#  'gumdrops',
#  "colman's",
#  'gao',
#  'phoron',
#  'multi-grain',
#  'pangasius',
#  'panetiniâ®',
#  'nibletsâ®',
#  'olivada',
#  'mark',
#  'delicata',
#  'frankfurters',
#  'nielsen-massey',
#  'organicâ®',
#  'pane',
#  'cups',
#  'do',
#  'ricard',
#  'evans',
#  '-half',
#  'honeysuckle',
#  'rusk',
#  'asti',
#  'xuxu',
#  'fat-trimmed',
#  'cornstarch',
#  'shanghai-style',
#  'streusel',
#  'poundcake',
#  'wensleydale',
#  'india',
#  'chilcostle',
#  'calabrese',
#  'chourico',
#  'haloumi',
#  'assam',
#  'martha',
#  'granita',
#  'cotto',
#  '00',
#  "chik''n",
#  'kochu',
#  'darjeeling',
#  'nakano',
#  'neapolitan',
#  '96%',
#  'german',
#  'granary',
#  'gammon',
#  'mccormickâ®',
#  'hint',
#  'ocean',
#  'george',
#  'tony',
#  'fruitcake',
#  'gravlax',
#  'harvest',
#  'garbanzos',
#  '-basil',
#  'sports',
#  'ceci',
#  'moose',
#  'hellmannã¢â‚¬â„¢',
#  'shred',
#  'than',
#  'deluxe',
#  'gember',
#  '100%',
#  'firmli',
#  'soybeans',
#  'ribeye',
#  'mahlab',
#  'mince',
#  'chicharron',
#  'blueberri',
#  'arame',
#  'blackcurrant',
#  'wasabe',
#  'muscovy',
#  'kippers',
#  'menta',
#  'sweeteners',
#  'wok',
#  'tabbouleh',
#  'skippy',
#  'budweiser',
#  'basa',
#  'habas',
#  '43',
#  'pat',
#  'wolfberries',
#  'nu-salt',
#  'vegetable-filled',
#  'freeze-dried',
#  'romana',
#  'belacan',
#  'poured',
#  'gravenstein',
#  'dream',
#  'argo',
#  'sardi',
#  'kha',
#  'benne',
#  'raki',
#  'mondavi',
#  'crumble',
#  'beech',
#  'ornamental',
#  'hines',
#  'bag',
#  'galliano',
#  'bear',
#  'semi-soft',
#  'riblets',
#  'ogura-an',
#  'jujubes',
#  'pain',
#  'alouette',
#  'bluefish',
#  'big',
#  'butterhead',
#  'crunch',
#  'hijiki',
#  'magret',
#  'octopus',
#  'shaped',
#  'arak',
#  'hake',
#  'despelette',
#  'scape',
#  'muscavado',
#  'amarena',
#  'victoria',
#  'tortelloni',
#  'duncan',
#  'hershey',
#  'dew',
#  'dulong',
#  'abbamele',
#  'road',
#  "cox's",
#  'miswa',
#  'liquorice',
#  'prik',
#  'fiddlehead',
#  'rouget',
#  'pasteurized',
#  'true',
#  'filipino',
#  'recaito',
#  'tomate',
#  'germain',
#  'bramley',
#  'bunches',
#  'surimi',
#  'jamon',
#  'daiya',
#  'pekoe',
#  'loofah',
#  'whiteâ®',
#  'colada',
#  'maca',
#  'no-stick',
#  'knoflook',
#  '100',
#  'grilling',
#  'chopmeat',
#  'lambic',
#  'soft-shelled',
#  'pinhead',
#  'promis',
#  'fluff',
#  'artificial',
#  'bordelaise',
#  'yuba',
#  'cepe',
#  'meats',
#  'v',
#  'vera',
#  '50%',
#  'vienna',
#  'nido',
#  'tubettini',
#  'foccacia',
#  'bagel',
#  'krachai',
#  'activ',
#  'betty',
#  'demi',
#  'hurst',
#  'dickel',
#  'aquavit',
#  'multipurpose',
#  'peapods',
#  'horse',
#  'pareve',
#  'pekin',
#  'burro',
#  'monte',
#  'makers',
#  'absinthe',
#  'lingcod',
#  'garbonzo',
#  'greekstyl',
#  'primavera',
#  'dreamfields',
#  'angus',
#  'glacã©s',
#  'blackpepper',
#  'ronzoni',
#  'dragon',
#  'val',
#  'fraise',
#  'pullman',
#  'jowl',
#  'ranch-style',
#  'ataulfo',
#  'mae',
#  'wheel',
#  'lettuces',
#  'cumberl',
#  'castelvetrano',
#  'ti',
#  'grind',
#  'cupcakes',
#  'century',
#  'haricot',
#  'dhaniya',
#  'topside',
#  'yoplait',
#  'filã©',
#  'breadcrumb',
#  'crumpet',
#  'cholent',
#  'cones',
#  'block',
#  'shiromiso',
#  'nondairy',
#  'silk',
#  'cal',
#  'spiny',
#  'patties',
#  'chiltepã\xadn',
#  'potassium',
#  'friselle',
#  'smart',
#  'hoagi',
#  'trang',
#  'beetroot',
#  'fiber',
#  'unhulled',
#  'poi',
#  'olie',
#  'mantou',
#  'qua',
#  'poolish',
#  'ammonium',
#  'gel',
#  'sangiovese',
#  'chaurice',
#  'soy-based',
#  'farfallini',
#  'beverages',
#  'chobani',
#  'hogue',
#  'maraschino',
#  'kataifi',
#  'picnic',
#  'tipo',
#  'fryers',
#  'ratatouille',
#  'kippered',
#  'gnocchetti',
#  'azteca',
#  'robusto!â®',
#  'snip',
#  'jarred',
#  'accompaniment',
#  'conchiglie',
#  'raguâ®',
#  'graviera',
#  'lambrusco',
#  'cheong',
#  'bai',
#  'grains',
#  'shin',
#  'guacamol',
#  'sloe',
#  'unsweeten',
#  'low-moisture',
#  'squirrel',
#  'kamut',
#  'breader',
#  'souchong',
#  'paradise',
#  'fedelini',
#  'piquin',
#  'bock',
#  'hip',
#  'third',
#  'woksaus',
#  'sevruga',
#  'spreadable',
#  'high-fructose',
#  'doubl',
#  'robert',
#  'huckleberries',
#  'pinch',
#  'sucrolose',
#  'macarons',
#  'lox',
#  'mooli',
#  'blackened',
#  'amba',
#  'amberjack',
#  'lap',
#  'estancia',
#  'oriental',
#  'melissa',
#  'bratwurst',
#  'phoran',
#  'evapor',
#  'tradicional',
#  'tropic',
#  'barramundi',
#  'brittle',
#  'piccolini',
#  'energy',
#  'kingfish',
#  'pocket',
#  'boiler',
#  'perfect',
#  'macadamias',
#  'del',
#  'skin-on',
#  'ladys',
#  'goma',
#  'longaniza',
#  'kappa',
#  'cotechino',
#  'vinaigrett',
#  'genmai',
#  'dijonnaise',
#  'romanesco',
#  'dole',
#  'bigoli',
#  'comice',
#  'muscadet',
#  'bark',
#  'secret',
#  'velvet',
#  'psyllium',
#  'kettle',
#  'verjuice',
#  'hops',
#  'maifun',
#  'aloe',
#  'jagermeister',
#  'samphire',
#  'woods',
#  'cheek',
#  'crabapples',
#  'spot',
#  'neem',
#  'zatarainâ€™s',
#  'niblets',
#  'corncobs',
#  'nettle',
#  'caciotta',
#  'honeycomb',
#  'tender',
#  'pro.activ',
#  'pike',
#  'ranchero',
#  "chachere's",
#  'petits',
#  'wieners',
#  'riso',
#  'chateaubri',
#  'chowchow',
#  'poupon',
#  'barberries',
#  'tabascoâ®',
#  'spumante',
#  'chioggia',
#  'chartreuse',
#  'sesame-ginger',
#  'portuguese',
#  'saltpeter',
#  'gebhardt',
#  'licor',
#  'fume',
#  'angelica',
#  'nuggets',
#  'laksa',
#  'honey-flavored',
#  'nian',
#  'better',
#  'escalopes',
#  'challenge',
#  'anardana',
#  'cardoons',
#  'imperial',
#  'malbec',
#  'amontillado',
#  'orchid',
#  'varieti',
#  'everglades',
#  'ascorbic',
#  'mian',
#  'arrow',
#  'rape',
#  'arrabbiata',
#  'sheepshead',
#  'moonshine',
#  'alexia',
#  'opal',
#  'dogfish',
#  'ready-made',
#  'crockerâ„¢',
#  'falafel',
#  'farmhouse',
#  'biga',
#  'blacan',
#  'camellia',
#  'chua',
#  'ferns',
#  'ketjap',
#  'originalsâ®',
#  'spear',
#  'pinipig',
#  'bayonne',
#  'kampyo',
#  'arctic',
#  'bã©nã©dictine',
#  'meat-filled',
#  'heath',
#  'dinosaur',
#  'nen',
#  'hickory-flavored',
#  'steamersâ„¢',
#  'trenne',
#  'crawford',
#  'sablefish',
#  'mazolaâ®',
#  'hakusai',
#  'farmsâ®',
#  'petrale']

# %%
model = LogisticRegression(multi_class = 'ovr')
score = cross_validate(model, X, y, return_train_score=False)
score["test_score"].mean()
# Out:
# 0.7812892511427579

# %%
model.fit(X, y)
submission = model.predict(X_test)
submission_df = pd.Series(submission, index=testdex).rename('cuisine')
submission_df.to_csv("logistic_baseline.csv", index=True, header=True)

# %%
tfidf = TfidfVectorizer(binary=True)
tfidf.fit_transform(df['ingredients']).astype(float)

X = tfidf.transform(df.loc[traindex, 'ingredients'])
X_test = tfidf.transform(df.loc[testdex, 'ingredients'])

score = cross_validate(model, X, y, return_train_score=False)
score["test_score"].mean()
# Out:
# 0.7743246798732185

# %%
model.fit(X, y)
submission = model.predict(X_test)
submission_df = pd.Series(submission, index=testdex).rename('cuisine')
submission_df.to_csv("logistic_tfidf.csv", index=True, header=True)
